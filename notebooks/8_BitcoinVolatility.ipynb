# %%
import os
import sys

import pandas as pd
import pandas_datareader.data as web

import numpy as np
from scipy import stats

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import linear_model

sys.path.append(os.path.abspath(os.path.join(os.path.dirname(os.getcwd()))))

from src.analysis_logic import AnalysisLogic, FitMethods

sns.set_style("darkgrid")

# %% [markdown]
# Data source: https://www.kaggle.com/datasets/mczielinski/bitcoin-historical-data

# %% [markdown]
# # Get historical data

# %%
filepath = os.path.join("..", "data", "bitstampUSD_1-min_data_2012-01-01_to_2021-03-31.csv")

# %%
df = pd.read_csv(filepath)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4857377 entries, 0 to 4857376
# Data columns (total 8 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Timestamp          int64
#  1   Open               float64
#  2   High               float64
#  3   Low                float64
#  4   Close              float64
#  5   Volume_(BTC)       float64
#  6   Volume_(Currency)  float64
#  7   Weighted_Price     float64
# dtypes: float64(7), int64(1)
# memory usage: 296.5 MB

# %% [markdown]
# ## Convert timestamps to datatime objects and set as index

# %%
df["Timestamp"] = pd.to_datetime(df["Timestamp"], unit='s')
df = df.set_index("Timestamp", drop=True)
df = df[df.index > pd.to_datetime('2012-01-01')]

# %% [markdown]
# ## Check for null values

# %%
sns.heatmap(df.isnull(), cmap="binary", vmin=0, vmax=1)
# Out:
# <AxesSubplot: ylabel='Timestamp'>

# %% [markdown]
# ## Drop null values

# %%
df = df.dropna().reset_index().set_index("Timestamp", drop=True)

# %%
# Double check to see if any null values remain
sns.heatmap(df.isnull(), cmap="binary", vmin=0, vmax=1)
# Out:
# <AxesSubplot: ylabel='Timestamp'>

# %% [markdown]
# ## Check for outliers

# %%
ax = sns.scatterplot(x=df.index, y="Close", data=df)
ax.set_yscale("log")

# %% [markdown]
# ## Resample data
# Since we don't really need minute data for our analysis, we can just resample and see if it disappears

# %%
# business month start frequency
df = df.resample("BMS").apply({
    'Open'  : 'first',
    'High'  : 'max',
    'Low'   : 'min',
    'Close' : 'last',
})

# %% [markdown]
# No more outliers in monthly data

# %%
ax = sns.scatterplot(x=df.index, y="Close", data=df)
ax.set_yscale("log")

# %%
df.tail()
# Out:
#                 Open      High       Low     Close
# Timestamp
# 2020-11-02  13762.00  19864.15  13220.00  19700.19
# 2020-12-01  19703.53  29300.00  17569.58  28992.79
# 2021-01-01  28999.63  42000.00  27734.00  33141.38
# 2021-02-01  33110.32  58354.14  32333.01  45240.96
# 2021-03-01  45261.56  61781.83  45020.25  58778.18

# %% [markdown]
# However, the data is not the most recent, only until Mar 2021. Lets get the latest data

# %% [markdown]
# # Get latest data and concatenate

# %%
df2 = web.get_data_yahoo("BTC-USD", interval="m", start=df.index[-1] + pd.Timedelta(days=31))

# %%
# At present we don't need this data
df2 = df2.drop(["Volume", "Adj Close"], axis=1)

# %%
df = pd.concat([df, df2])

# %% [markdown]
# # Plot

# %%
ax = sns.scatterplot(x=df.index, y="Close", data=df)
ax.set_yscale("log")

ax.set_ylabel("Price")
ax.set_xlabel("Time")
# Out:
# Text(0.5, 0, 'Time')

# %% [markdown]
# ## Monthly returns

# %%
ax = sns.lineplot(x=df.index, y=df["Close"].pct_change() * 100)

ax.set_ylabel("Monthly returns (%)")
ax.set_xlabel("Time")
# Out:
# Text(0.5, 0, 'Time')

# %% [markdown]
# # Calculate volatility

# %%
months_in_window = 3
months_in_year = 12
annualization_factor = months_in_year / months_in_window

# %% [markdown]
# $$  $$

# %% [markdown]
# ## Method 1

# %%
df['log_rtn_close'] = np.log(df["Close"] / df["Close"].shift(1))
df.fillna(0, inplace = True)
df['real_volatility_close'] = df['log_rtn_close'].rolling(window=months_in_window).std(ddof=0) * np.sqrt(months_in_year)

# %% [markdown]
# ## Method 2

# %%
df['log_rtn_close'] = np.log(df['Close']).diff()
df['real_volatility_close'] = np.sqrt(np.square(df['log_rtn_close']).rolling(months_in_window).sum() * annualization_factor)

# %% [markdown]
# Convert datetime index to number of months from starting date, x data needs to be reshaped for sklearn fitting

# %%
x = df.index[months_in_window:].factorize()[0].reshape(-1, 1)
y = df["real_volatility_close"].values[months_in_window:]

# %%
len(x) == len(y)
# Out:
# True

# %% [markdown]
# ## Fit with linear regression model

# %%
regr = linear_model.LinearRegression()
regr.fit(x, y)
# Out:
# LinearRegression()

# %%
ax = sns.lineplot(x=df.index, y="real_volatility_close", data=df)
sns.lineplot(x=df.index[months_in_window:], y=regr.predict(x), color="C1", ax=ax)

ax.set_ylabel("3 month annualized volatility")
# Out:
# Text(0, 0.5, '3 month annualized volatility')

# %% [markdown]
# The data is quite clear that the 3 month annualized volatility of BTC is decreasing

# %% [markdown]
# # Comparison with SPY volatility

# %%
spy = web.get_data_yahoo("SPY", interval="m", start=df.index[0])

# %%
spy['log_rtn_close'] = np.log(spy["Close"] / spy["Close"].shift(1))
spy.fillna(0, inplace = True)
spy['real_volatility_close'] = spy['log_rtn_close'].rolling(window=months_in_window).std(ddof=0) * np.sqrt(12)

# %% [markdown]
# ## Fit SPY volatility

# %%
x_spy = spy.index[months_in_window:].factorize()[0].reshape(-1, 1)
y_spy = spy["real_volatility_close"].values[months_in_window:]

regr_spy = linear_model.LinearRegression()
regr_spy.fit(x_spy, y_spy)
# Out:
# LinearRegression()

# %%
ax = sns.lineplot(x=df.index, y="real_volatility_close", data=df, label="BTC-USD")
sns.lineplot(x=df.index[months_in_window:], y=regr.predict(x), linestyle="--", color="C0", ax=ax, label="BTC-USD linear fit")

sns.lineplot(x=spy.index, y="real_volatility_close", data=spy, ax=ax, label="SPY")
sns.lineplot(x=spy.index[months_in_window:], y=regr_spy.predict(x_spy), linestyle="--", color="C1", ax=ax, label="SPY linear fit")

ax.set_ylabel("3 month annualized volatility")
ax.set_xlabel("Time")
# Out:
# Text(0.5, 0, 'Time')

# %%
ax = sns.lineplot(x=df.index, y="real_volatility_close", data=df, label="BTC-USD")
sns.lineplot(x=df.index[months_in_window:], y=regr.predict(x), linestyle="--", color="C0", ax=ax, label="BTC-USD linear fit")

sns.lineplot(x=spy.index, y="real_volatility_close", data=spy, ax=ax, label="SPY")
sns.lineplot(x=spy.index[months_in_window:], y=regr_spy.predict(x_spy), linestyle="--", color="C1", ax=ax, label="SPY linear fit")

ax.set_ylabel("3 month annualized volatility")
ax.set_xlabel("Time")
# Out:
# Text(0.5, 0, 'Time')

# %% [markdown]
# # Relative volatility

# %%
x_rel = spy.index[months_in_window:].factorize()[0].reshape(-1, 1)
y_rel = df["real_volatility_close"][months_in_window:].values / spy["real_volatility_close"][months_in_window:].values

regr_rel = linear_model.LinearRegression()
regr_rel.fit(x_rel, y_rel)
# Out:
# LinearRegression()

# %%
ax = sns.lineplot(x=spy.index, y=df["real_volatility_close"].values / spy["real_volatility_close"].values, color="C1")
sns.lineplot(x=spy.index[months_in_window:], y=regr_rel.predict(x_rel), color="C1", ax=ax, linestyle="--", label="Linear fit")

for i in np.arange(1, 7, 1):
    sns.lineplot(x=spy.index[months_in_window:], y=regr_rel.predict(x_rel) * i, ax=ax, color=f"C{i}", linestyle="--")

ax.set_ylabel("Relative volatility (BTC-USD / SPY)")
ax.set_xlabel("")
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# # Fanciful projections

# %%
x_extrapolation = pd.date_range(start=spy.index[0], periods=175, freq="m")

# %%
fig, (ax, ax1) = plt.subplots(nrows=2, sharex="col")

sns.lineplot(x=spy.index, y=df["real_volatility_close"].values / spy["real_volatility_close"].values, ax=ax, color="C1")
sns.lineplot(x=spy.index[months_in_window:], y=regr_rel.predict(x_rel), color="C1", ax=ax, linestyle="--", label="Linear fit")

for i in np.arange(2, 6, 1):
    sns.lineplot(x=x_extrapolation, y=regr_rel.predict(x_extrapolation.factorize()[0].reshape(-1, 1)) * i, ax=ax, color=f"C{i}", linestyle="--")

ax.set_ylabel("Relative volatility (BTC-USD / SPY)")
ax.set_xlabel("")

cycle_start = 22
progression = [1, 3, 5, 7]
# error bars are just a guesstimation lol
error_bars = [0, 3, 5, 7]

for idx, i in enumerate(progression):
    peak = x_extrapolation[cycle_start * i]
    ax.axvline(peak, color=f"C{i+1}")
    ax1.axvline(peak, label=f"{peak.month}-{peak.year}", color=f"C{i+1}")
    
    ax.axvspan(xmin=peak - pd.DateOffset(months=error_bars[idx]), xmax=peak + pd.DateOffset(months=error_bars[idx]), alpha=0.2, color=f"C{i+1}")
    ax1.axvspan(xmin=peak - pd.DateOffset(months=error_bars[idx]), xmax=peak + pd.DateOffset(months=error_bars[idx]), alpha=0.2, color=f"C{i+1}")

ax.legend()

sns.lineplot(x=df.index, y="Close", data=df, ax=ax1)
ax1.set_yscale("log")

# %%
f"Prediction of a cycle peak around {x_extrapolation[cycle_start * progression[-1]].year}\
-{x_extrapolation[cycle_start * progression[-1]].month} ± {error_bars[-1]} months, with a relative \
volatility peak of around {int(regr_rel.predict(x_extrapolation.factorize()[0].reshape(-1, 1))[22*7] * 5)}"
# Out:
# 'Prediction of a cycle peak around 2024-10 ± 7 months, with a relative volatility peak of around 10'

# %% [markdown]
# ## Exponentionally decaying sinusoid

# %%
analysis = AnalysisLogic()

# %%
x_rel = x_rel.reshape(-1)

# %%
fit_x, fit_y, result = analysis.perform_fit(x=x_rel, y=y_rel, fit_function=FitMethods.sineexponentialdecay)

# %%
result.best_values
# Out:
# {'offset': 12.948993291973322,
#  'beta': 1,
#  'lifetime': 59.206004689552806,
#  'frequency': 0.02080713516639702,
#  'phase': 5.638845075505936,
#  'amplitude': 33.42265862001895}

# %%
1 / result.best_values["frequency"]
# Out:
# 48.06043657634204

# %% [markdown]
# fit reveals a 47.3 month period, very close of the approx. 4 year btc halving cycle

# %%
fig, (ax, ax1) = plt.subplots(nrows=2, sharex="col")

sns.lineplot(x=x_rel, y=y_rel, ax=ax)
sns.lineplot(x=fit_x, y=fit_y, ax=ax)

sns.lineplot(x=np.arange(0, 200), y=result.eval(x=np.arange(0, 200)), ax=ax)

sns.lineplot(x=df.index.factorize()[0], y="Close", data=df, ax=ax1)
ax1.set_yscale("log")


# extract sine frequency and phase to find first trough
first_trough = (1 / (result.best_values["frequency"]) - result.best_values["phase"])
# for first peak, phase shift by pi/2
first_peak = first_trough - 1 / (result.best_values["frequency"] * 2)

# it stands to reason that volatility peaks on the run up to the peak, and not the peak itself
# so applying some positive offset may reveal the peak
peak_offset = 5

# it also stands to reason that volatility bottoms on the run down to the low, and not the low itself
# so applying some negative offset may reveal the low
bottom_offset = -5

# note that these are simply speculation, but it does fit the measured data rather well

for i in range(0, 4):
    trough = first_trough + (i / result.best_values["frequency"]) + bottom_offset
    ax.axvline(trough, color="C3")
    ax1.axvline(trough, color="C3")
    
    peak = first_peak + (i / result.best_values["frequency"]) + peak_offset
    ax.axvline(peak, color="C2")
    ax1.axvline(peak, color="C2")
    
ax.set_ylabel("Relative volatility")
ax1.set_xlabel("Months")
# Out:
# Text(0.5, 0, 'Months')

# %% [markdown]
# applying an offset of (+/-)5 months to the volatility sine peaks/troughs seems to match the first 3 cycles quite well (within 2 months of the actual cycle peak/troughs)
#
# To predict the next cycle trough and peak, we simply plug in the value for the next trough and peak

# %%
i = 2
num_months_to_trough = first_trough + i / (result.best_values["frequency"]) + bottom_offset
i = 3
num_months_to_peak = first_peak + i / (result.best_values["frequency"]) + peak_offset

print("Months from starting point:", num_months_to_trough, num_months_to_peak)
# Out:
# Months from starting point: 133.5424646535202 167.5726829416912

# %% [markdown]
# In date units

# %%
pd.date_range(start=spy.index[0], periods=int(num_months_to_trough), freq="m")[-1]
# Out:
# Timestamp('2022-12-31 00:00:00', freq='M')

# %%
pd.date_range(start=spy.index[0], periods=int(num_months_to_peak), freq="m")[-1]
# Out:
# Timestamp('2025-10-31 00:00:00', freq='M')

# %% [markdown]
# This implies a cycle low in Dec 2022, and a cycle peak in Oct 2025, error margins of a few months or so

# %% [markdown]
# # Sine fit to price data

# %% [markdown]
# The standard log price model will not converge to a sine, so we can apply a simple exponentional or linear model to serve as an effective "baseline"

# %%
x = df.index.factorize()[0]
y = np.log(df["Close"])

# %%
x_dates = pd.date_range(start=df.index[0], periods=len(x), freq="m")

ax = sns.lineplot(x=x_dates, y=y)


fit_x_lin, fit_y_lin, result_lin = analysis.perform_fit(x=x, y=y, fit_function=FitMethods.linear)
#sns.lineplot(x=fit_x_lin, y=fit_y_lin, ax=ax, label="Linear fit")

fit_x_exp, fit_y_exp, result_exp = analysis.perform_fit(x=x, y=y, fit_function=FitMethods.decayexponential)
#sns.lineplot(x=fit_x_exp, y=fit_y_exp, ax=ax, label="Exponential fit")

fit_x_hyp, fit_y_hyp, result_hyp = analysis.perform_fit(x=x, y=y, fit_function=FitMethods.hyperbolicsaturation)
#sns.lineplot(x=fit_x_hyp, y=fit_y_hyp, ax=ax, label="Hyperbolic fit")

# Extrapolations
x_extra = np.arange(0, 200)
x_dates_extra = pd.date_range(start=df.index[0], periods=len(x_extra), freq="m")

sns.lineplot(x=x_dates_extra, y=result_lin.eval(x=x_extra), ax=ax, linestyle="--", label="Linear")
sns.lineplot(x=x_dates_extra, y=result_exp.eval(x=x_extra), ax=ax, linestyle="--", label="Exponential")
sns.lineplot(x=x_dates_extra, y=result_hyp.eval(x=x_extra), ax=ax, linestyle="--", label="Hyperbolic")

ax.set_ylabel("log(close)")
# Out:
# Text(0, 0.5, 'log(close)')

# %% [markdown]
# Subtracting the points from the exponential

# %%
fig, (ax, ax1, ax2) = plt.subplots(nrows=3, sharex="col", figsize=(8, 8))

x_dates = pd.date_range(start=df.index[0], periods=len(x), freq="m")
x_dates_exptrapolated = pd.date_range(start=df.index[0], periods=200, freq="m")

# Linear
y_shifted_lin = y - result_lin.eval(x=x)
sns.lineplot(x=x_dates, y=y_shifted_lin, ax=ax)

_, _, result_st_lin = analysis.perform_fit(x=x, y=y_shifted_lin, fit_function=FitMethods.sinetriplewithexpdecay)
sns.lineplot(x=x_dates_exptrapolated, y=result_st_lin.eval(x=np.arange(0, 200)), ax=ax, label="sinetriplewithexpdecay")

_, _, result_sd_lin = analysis.perform_fit(x=x, y=y_shifted_lin, fit_function=FitMethods.sinedoublewithexpdecay)
sns.lineplot(x=x_dates_exptrapolated, y=result_sd_lin.eval(x=np.arange(0, 200)), ax=ax, label="sinedoublewithexpdecay")

# Exponential
y_shifted_exp = y - result_exp.eval(x=x)
sns.lineplot(x=x_dates, y=y_shifted_exp, ax=ax1)

_, _, result_st_exp = analysis.perform_fit(x=x, y=y_shifted_exp, fit_function=FitMethods.sinetriplewithexpdecay)
sns.lineplot(x=x_dates_exptrapolated, y=result_st_exp.eval(x=np.arange(0, 200)), ax=ax1, label="sinetriplewithexpdecay")

_, _, result_sd_exp = analysis.perform_fit(x=x, y=y_shifted_exp, fit_function=FitMethods.sinedoublewithexpdecay)
sns.lineplot(x=x_dates_exptrapolated, y=result_sd_exp.eval(x=np.arange(0, 200)), ax=ax1, label="sinedoublewithexpdecay")

# Hyperbolic
y_shifted_hyp = y - result_hyp.eval(x=x)
sns.lineplot(x=x_dates, y=y_shifted_hyp, ax=ax2)

_, _, result_st_hyp = analysis.perform_fit(x=x, y=y_shifted_hyp, fit_function=FitMethods.sinetriplewithexpdecay)
sns.lineplot(x=x_dates_exptrapolated, y=result_st_hyp.eval(x=np.arange(0, 200)), ax=ax2, label="sinetriplewithexpdecay")

_, _, result_sd_hyp = analysis.perform_fit(x=x, y=y_shifted_hyp, fit_function=FitMethods.sinedoublewithexpdecay)
sns.lineplot(x=x_dates_exptrapolated, y=result_sd_hyp.eval(x=np.arange(0, 200)), ax=ax2, label="sinedoublewithexpdecay")

# Linear
peak_st_lin = 160
price_peak_lin = int(np.exp(result_lin.eval(x=peak_st_lin) + result_st_lin.eval(x=peak_st_lin)))
bottom_sd_lin = 140
price_bottom_lin = int(np.exp(result_lin.eval(x=bottom_sd_lin) + result_sd_lin.eval(x=bottom_sd_lin)))

ax.axvline(x_dates_exptrapolated[peak_st_lin], color="C2", label=f"peak = {price_peak_lin:,} USD", linestyle="--")
ax.axvline(x_dates_exptrapolated[bottom_sd_lin], color="C3", label=f"bottom = {price_bottom_lin:,} USD", linestyle="--")

# Exponential
peak_st_exp = 163
price_peak_exp = int(np.exp(result_exp.eval(x=peak_st_exp) + result_st_exp.eval(x=peak_st_exp)))
bottom_sd_exp = 140
price_bottom_exp = int(np.exp(result_exp.eval(x=bottom_sd_exp) + result_sd_exp.eval(x=bottom_sd_exp)))

ax1.axvline(x_dates_exptrapolated[peak_st_exp], color="C2", label=f"peak = {price_peak_exp:,} USD", linestyle="--")
ax1.axvline(x_dates_exptrapolated[bottom_sd_exp], color="C3", label=f"bottom = {price_bottom_exp:,} USD", linestyle="--")

# Hyperbolic
peak_st_hyp = 163
price_peak_hyp = int(np.exp(result_hyp.eval(x=peak_st_hyp) + result_st_hyp.eval(x=peak_st_hyp)))
bottom_sd_hyp = 137
price_bottom_hyp = int(np.exp(result_hyp.eval(x=bottom_sd_hyp) + result_sd_hyp.eval(x=bottom_sd_hyp)))

ax2.axvline(x_dates_exptrapolated[peak_st_hyp], color="C2", label=f"peak = {price_peak_hyp:,} USD", linestyle="--")
ax2.axvline(x_dates_exptrapolated[bottom_sd_hyp], color="C3", label=f"bottom = {price_bottom_hyp:,} USD", linestyle="--")


ax.set_ylabel("log(close) - linear")
ax1.set_ylabel("log(close) - exponential")
ax2.set_ylabel("log(close) - hyperbolic")

ax.legend()
ax1.legend()
ax2.legend()

# %% [markdown]
# Clearly the linear model is wildly incorrect, while the exponentional decay model (so far) is holding up quite well. The hyperbolic model is decent, but seems wayy too bullish regarding the peak.
